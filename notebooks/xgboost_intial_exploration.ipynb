# %% [markdown]
# ## Load packages

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %cd ..

# %%
import pandas as pd

# %% [markdown]
# ## Data exploration

# %%
DATA_PATH = r'/Users/marthygarcia/Documents/GitHub/IFT6759_B_H23/data/interim/traffic/traffic.txt' #'/Users/marthygarcia/Documents/GitHub/IFT6759_B_H23/data/interim/exchange_rate/exchange_rate.txt'

# %%
df = pd.read_csv(DATA_PATH)
df.head()
# Out:
#    0.004800  0.014600  0.028900  0.014200  0.006400  0.023200  0.016200  \
# 0    0.0072    0.0148    0.0350    0.0174    0.0084    0.0240    0.0201
# 1    0.0040    0.0101    0.0267    0.0124    0.0049    0.0170    0.0127
# 2    0.0039    0.0060    0.0218    0.0090    0.0029    0.0118    0.0088
# 3    0.0042    0.0055    0.0191    0.0082    0.0024    0.0095    0.0064
# 4    0.0040    0.0071    0.0213    0.0106    0.0038    0.0093    0.0076
#
#    0.024200  0.034100  0.037500  ...  0.005100.14  0.005100.15  0.007400  \
# 0    0.0338    0.0434    0.0381  ...       0.0036       0.0036    0.0107
# 1    0.0255    0.0332    0.0309  ...       0.0030       0.0030    0.0043
# 2    0.0163    0.0211    0.0199  ...       0.0033       0.0033    0.0019
# 3    0.0087    0.0144    0.0226  ...       0.0049       0.0049    0.0011
# 4    0.0066    0.0113    0.0216  ...       0.0107       0.0107    0.0009
#
#    0.007900.8  0.005100.16  0.005100.17  0.033900.2  0.005100.18  0.010000.2  \
# ...
